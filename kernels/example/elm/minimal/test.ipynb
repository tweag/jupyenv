# %%
import Browser
import Html exposing (..)
import Html.Events exposing (..)

type Msg = Inc | Dec
type alias Model = Int

init : () -> (Model, Cmd Msg)
init _ = (0, Cmd.none)

subscriptions : Model -> Sub Msg
subscriptions _ = Sub.none

view : Model -> Html Msg
view model = div [] [ text "hello Elm!" ]
        
update : Msg -> Model -> (Model, Cmd Msg)
update msg model =
    case msg of
        Inc -> (model + 1, Cmd.none)
        Dec -> (model - 1, Cmd.none)
        
main =
    Browser.element 
        { init = init
        , view = view
        , update = update
        , subscriptions = subscriptions
        }
    
-- compile-code
# Out:
# <div id="elm-div-18"></div>
